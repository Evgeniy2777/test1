# %% [markdown]
# <a href="https://colab.research.google.com/github/Evgeniy2777/test1/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame({'x':[1,2,3], 'y':[2,4,1]})
df
# Out:
#    x  y
# 0  1  2
# 1  2  4
# 2  3  1

# %%
df.drop(1,axis=0,inplace=True)
df
# Out:
#    x  y
# 0  1  2
# 2  3  1

# %%
df.reset_index(drop=True)
df
# Out:
#    x  y
# 0  1  2
# 2  3  1

# %%
del df['x']
df
# Out:
#    y
# 0  2
# 1  4
# 2  1

# %%
df1=pd.DataFrame({'x':[1,3,2],'y':[2,4,1]})
df2=pd.DataFrame({'x':[3,1,2],'y':[0,2,2]})
print(df1>=df2)
# Out:
#        x      y
# 0  False   True
# 1   True   True
# 2   True  False

# %%
print(df1[df1>1])
print(df2[(df2<2) & (df2>0)])
print(df2[(df2<1) | (df2>2)])
# Out:
#      x    y
# 0  NaN  2.0
# 1  3.0  4.0
# 2  2.0  NaN
#      x   y
# 0  NaN NaN
# 1  1.0 NaN
# 2  NaN NaN
#      x    y
# 0  3.0  0.0
# 1  NaN  NaN
# 2  NaN  NaN

# %%
from pandas.core.dtypes.missing import isna_all
df3=df2[(df2<1) | (df2>2)]
print(df3.isna())
print(df3.isnull().loc[df3['y']==False])
1+1
# Out:
#        x      y
# 0  False  False
# 1   True   True
# 2   True   True
#        x      y
# 0  False  False
# 2
